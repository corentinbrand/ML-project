# %% [markdown]
# # Introduction générale : GUS
#
# - Objectif du projet
# - Présentation du dataset
# - Sommaire global de l’étude
#
#
# # Analyse exploratoire des données :  Chris
#
# - Chargement et vérification des données
# - Analyse univariée
# - Analyse bivariée
# - Analyse en Composantes Principales (ACP)
# - Transfo des données
# - 80/20
#
#
# # Problème de classification : prédiction du risque cardiaque
#
# ## COCO :
#
# - Présentation du problème de classification : dire que ceest plus grave de pas detecter un risk que d'en inventer un
#
# ## Régression logistique
# - Sans sélection de variables
# - Avec sélection / pénalisation
#
#
# ## KNN et SVM : Gus
#
# ## Arbres de classification et Random Forest : Deds
#
# ## Réseaux de neurones : Coco
#
# ## Comparaison des modèles de classification : Chris
#
# # Problème de régression : prédiction du LDL-cholestérol : Chris
# - Présentation du problème de régression : dire qu'en change de mesure ( MSE/RMSE, pq on peut pas ect)
#
# ## Modèles linéaires : Gus
# - Régression linéaire
# - Ridge / Lasso
#
# ## KNN et SVR : Chris
#
# ## CART de régression : coco
#
# ## Méthodes d’agrégation
# - Bagging
# - Random Forest
# - Boosting
#
# ## Réseaux de neurones : deds
#
# ## Comparaison des modèles de régression : gus
#
# # Comparaison globale et discussion : coco
# - Comparaison finale des approches
# - Interprétabilité vs performance
# - Robustesse et validation croisée
# - Analyse des limites du projet
#
# # Conclusion : chris
# - Résultats principaux
# - Enseignements méthodologiques
# - Perspectives possibles
#
# # Questions
# - Questions / échanges avec le jury
